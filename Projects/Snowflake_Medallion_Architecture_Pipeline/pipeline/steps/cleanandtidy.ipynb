# %%
CREATE OR REPLACE TABLE LASTUPDATE (
    STAMP TIMESTAMP_NTZ NOT NULL
);

INSERT INTO LASTUPDATE (STAMP)
VALUES (CAST(CONVERT_TIMEZONE('UTC', CURRENT_TIMESTAMP()) AS TIMESTAMP_NTZ));

# %%
-- Final cleanup of BRONZE tables
DROP TABLE IF EXISTS database_name.schema_name.BRONZE_RIDER;
DROP TABLE IF EXISTS database_name.schema_name.BRONZE_CUSTOMER;
DROP TABLE IF EXISTS database_name.schema_name.BRONZE_RESTAURANT;
DROP TABLE IF EXISTS database_name.schema_name.BRONZE_ORDERS;


DROP STAGE IF EXISTS database_name.schema_name.ORDERDATA;
